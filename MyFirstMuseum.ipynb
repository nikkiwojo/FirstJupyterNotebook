# %%
import pandas as pd

# %%
museum_df = pd.read_csv('museums.csv')
museum_df
# Out:
# /Users/nikki/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (9,14,21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         Museum ID                                        Museum Name  \
# 0      8400200098                    ALASKA AVIATION HERITAGE MUSEUM
# 1      8400200117                            ALASKA BOTANICAL GARDEN
# 2      8400200153  ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3      8400200143                ALASKA EDUCATORS HISTORICAL SOCIETY
# 4      8400200027                             ALASKA HERITAGE MUSEUM
# ...           ...                                                ...
# 33067  8405600184                   WYOMING STATE HISTORICAL SOCIETY
# 33068  8405600061                               WYOMING STATE MUSEUM
# 33069  8405600158      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# ...

# %%
# Which city or state has the most museums per capita?

state = museum_df['State (Administrative Location)']
city = museum_df['City (Administrative Location)']

def most_museums():
    if city.max() > state.max():
        return city.max()
    else:
        return state.max()

most_museums()
# Out:
# 'ZUNI'

# %%
# Which city or state has the lease museums per capita?

def least_museums():
    if city.min() < state.min():
        return city.min()
    else:
        return state.min()

least_museums()
# Out:
# '400 NEVIN AVE'

# %%
# How many zoos or aquariums exist in the United States?

condition = museum_df['Museum Type'] == 'ZOO, AQUARIUM, OR WILDLIFE CONSERVATION'

condition.value_counts()
# Out:
# False    32508
# True       564
# Name: Museum Type, dtype: int64

# %%
# How many zoos?

num_zoos = museum_df[museum_df['Museum Name'].str.contains('ZOO')]

num_zoos.count()
# Out:
# Museum ID                                   289
# Museum Name                                 289
# Legal Name                                  289
# Alternate Name                               35
# Museum Type                                 289
# Institution Name                             11
# Street Address (Administrative Location)    289
# City (Administrative Location)              289
# State (Administrative Location)             289
# Zip Code (Administrative Location)          289
# Street Address (Physical Location)          135
# City (Physical Location)                    135
# State (Physical Location)                   135
# Zip Code (Physical Location)                135
# Phone Number                                238
# Latitude                                    287
# Longitude                                   287
# Locale Code (NCES)                          287
# County Code (FIPS)                          263
# State Code (FIPS)                           289
# ...

# %%
# How many zoos?

num_aquari = museum_df[museum_df['Museum Name'].str.contains('AQUARIUM')]

num_aquari.count()
# Out:
# Museum ID                                   111
# Museum Name                                 111
# Legal Name                                  111
# Alternate Name                                7
# Museum Type                                 111
# Institution Name                              4
# Street Address (Administrative Location)    111
# City (Administrative Location)              111
# State (Administrative Location)             111
# Zip Code (Administrative Location)          111
# Street Address (Physical Location)           48
# City (Physical Location)                     48
# State (Physical Location)                    48
# Zip Code (Physical Location)                 48
# Phone Number                                 72
# Latitude                                    111
# Longitude                                   111
# Locale Code (NCES)                          110
# County Code (FIPS)                          103
# State Code (FIPS)                           111
# ...

# %%
# What museum had the highest revenue last year?

highest_rev = museum_df['Revenue'].max()
table = museum_df.loc[museum_df['Revenue'] == highest_rev]
mus_type = pd.DataFrame(data = table)

print(mus_type['Museum Name'])
# Out:
# 1090                     FRED LAWRENCE WHIPPLE OBSERVATORY
# 11883    ARNOLD ARBORETUM OF HARVARD UNIVERSITY JAMAICA...
# 11903                             AUTHUR M. SACKLER MUSEUM
# 11989                               BUSCH-REISINGER MUSEUM
# 12021        CENTER FOR CONSERVATION AND TECHNICAL STUDIES
# 12064                 COLLECTION OF SCIENTIFIC INSTRUMENTS
# 12148                                        FISHER MUSEUM
# 12151                                      FOGG ART MUSEUM
# 12179                           GENERAL ARTEMAS WARD HOUSE
# 12221                                       HARVARD FOREST
# 12226                       HARVARD UNIVERSITY ART MUSEUMS
# 12227                  HARVARD UNIVERSITY BOTANICAL MUSEUM
# 12228                          HARVARD UNIVERSITY HERBARIA
# 12229    HARVARD UNIVERSITY MINERALOGICAL AND GEOLOGICA...
# 12230     HARVARD UNIVERSITY MUSEUM OF COMPARATIVE ZOOLOGY
# 12231        HARVARD UNIVERSITY MUSEUMS OF NATURAL HISTORY
# ...

# %%
# How does the composition of museums differ across the country?

museum_df[['Museum Name', 'State (Administrative Location)']]
# Out:
#                                              Museum Name  \
# 0                        ALASKA AVIATION HERITAGE MUSEUM
# 1                                ALASKA BOTANICAL GARDEN
# 2      ALASKA CHALLENGER CENTER FOR SPACE SCIENCE TEC...
# 3                    ALASKA EDUCATORS HISTORICAL SOCIETY
# 4                                 ALASKA HERITAGE MUSEUM
# ...                                                  ...
# 33067                   WYOMING STATE HISTORICAL SOCIETY
# 33068                               WYOMING STATE MUSEUM
# 33069      WYOMING TERRITORIAL PARK HISTORIC ASSOCIATION
# 33070                      WYOMING TRANSPORTATION MUSEUM
# 33071                          YELLOWSTONE NATIONAL PARK
#
#       State (Administrative Location)
# 0                                  AK
# 1                                  AK
# 2                                  AK
# 3                                  AK
# 4                                  AK
# ...                               ...
# ...

# %%
# For each type of museum, statistical measure on income and revenue



income = museum_df['Income']
revenue = museum_df['Revenue']  

print(income.corr(revenue))
# Out:
# 0.7999153852772207

# %%
# Create a visualization of some aspect of the data set

import matplotlib.pyplot as plt
plt.rcParams.update({'font.size': 20, 'figure.figsize' :(10,8)})

# %%
museum_df['Income'].plot(kind = 'box')
# Out:
# <AxesSubplot:>

# %%
# Show a chart which shows the distribution of money across the data set

museum_df.plot(kind = 'scatter', x = 'Income', y = 'Revenue', title = "Income vs. Revenue");
